# %% [markdown]
# # PANDAS

# %% [markdown]
# ##### To setup venv
# ###### python -m venv venv
# ###### venv\Scripts\activate

# %%
import pandas as pd

# %% [markdown]
# ## Dataframe

# %% [markdown]
# ### Intro to Dataframe

# %%
df = pd.DataFrame([[1,2,3],
                   [4,5,6],
                   [7,8,9]],
                   columns=["A","B","C"],
                   index=["P","Q","R"])

# %%
print("head() \n",df.head())
print("head(1) \n",df.head(1))
print("head(2) \n",df.head(2))
print("head(3) \n",df.head(3))
print("tail() \n",df.tail())
print("tail(1) \n",df.tail(1))
print("tail(2) \n",df.tail(2))
print("tail(3) \n",df.tail(1))
# Out:
# head()
#     A  B  C
# P  1  2  3
# Q  4  5  6
# R  7  8  9
# head(1)
#     A  B  C
# P  1  2  3
# head(2)
#     A  B  C
# P  1  2  3
# Q  4  5  6
# head(3)
#     A  B  C
# P  1  2  3
# Q  4  5  6
# R  7  8  9
# tail()
#     A  B  C
# P  1  2  3
# Q  4  5  6
# R  7  8  9
# tail(1)
#     A  B  C
# R  7  8  9
# tail(2)
#     A  B  C
# Q  4  5  6
# R  7  8  9
# tail(3)
#     A  B  C
# R  7  8  9

# %%
print(df.columns)
print(df.columns.tolist())
# Out:
# Index(['A', 'B', 'C'], dtype='object')
# ['A', 'B', 'C']

# %%
print(df.index)
print(df.index.tolist())
# Out:
# Index(['P', 'Q', 'R'], dtype='object')
# ['P', 'Q', 'R']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, P to R
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df
# Out:
#    A  B  C
# P  1  2  3
# Q  4  5  6
# R  7  8  9

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df["A"].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %% [markdown]
# ## Loading Dataframes from files

# %%
coffee = pd.read_csv('./warmup_data/coffee.csv') #fastest

# %%
print(coffee.head())
print(coffee.tail())
print(coffee)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# ...

# %%
results = pd.read_feather('./data/results.feather')
# print(results)
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
olympics = pd.read_excel('./data/olympics-data.xlsx', sheet_name="results")  #slowest
# print(olympics)
olympics.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
result = pd.read_parquet('./data/results.parquet')
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %% [markdown]
# ### time of execution
# ### csv (0.0s) --> Fastest
# ### feather (0.1s)
# ### parquet (0.2s)
# ### excel (45.5s) --> Slowest

# %%
bios = pd.read_csv('./data/bios.csv')

# %%
bios.to_feather
# Out:
# <bound method DataFrame.to_feather of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.to_excel
# Out:
# <bound method NDFrame.to_excel of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.to_parquet
# Out:
# <bound method DataFrame.to_parquet of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# ## Accessing Data with Pandas

# %%
coffee.head(8)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
print(coffee)
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# ...

# %%
coffee.tail(7)
# Out:
#          Day Coffee Type  Units Sold
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(10,random_state=1) #randomly
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %% [markdown]
# #### locate specific
# ##### loc()
# ##### iloc() -> almost same as loc() but the upper index is not inclusive, where with loc() it was inclusive

# %%
# coffee.loc[#Rows , #Columns]
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
#slicing
print(coffee.loc[0:5])
print(coffee.loc[0:])
print(coffee.loc[5:])
print(coffee.loc[::2])
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# ...

# %%
print(coffee.loc[0:5,["Day","Units Sold"]])
# upper index is inclusive
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25

# %%
print(coffee.iloc[0:5, [0, 2]]) # used to access rows and columns but only using index value
# upper index is NOT inclusive
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
# coffee.index is already set to 'Day' (as shown in your variable summary)
# To access all rows where the index is 'Day', use .loc with the actual day name, e.g. "Monday"
# If you want to see all rows for "Monday":
coffee.loc["Monday":"Friday","Units Sold"]
# Out:
# Series([], Name: Units Sold, dtype: int64)

# %%
coffee.index = coffee.Day
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
coffee.index = coffee["Day"]
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %% [markdown]
# #### modifying the values by loc()

# %%
# To reset the index to default integer index:
coffee.index = range(len(coffee))
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# coffee = coffee.drop("Unites Sold", axis=1) # deleting the column

# %%
coffee.loc[1:5,["Units Sold"]] = 1000
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte        1000
# 2     Tuesday    Espresso        1000
# 3     Tuesday       Latte        1000
# 4   Wednesday    Espresso        1000
# 5   Wednesday       Latte        1000
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# #### Accessing single Values
# #### at()
# #### iat()

# %%
coffee.iat[0,0]
# Out:
# 'Monday'

# %%
# coffee.Day
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %% [markdown]
# ### Sorting of data

# %%
# To sort by multiple columns, pass a list to 'by'
# coffee.sort_values(by=["Units Sold", "Coffee Type"], ascending=False)
coffee.sort_values(by=["Units Sold", "Coffee Type"], ascending=[0,1]) # 0 for units sold for not ascending and 1 for coffee type for ascending
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso        1000
# 4   Wednesday    Espresso        1000
# 1      Monday       Latte        1000
# 3     Tuesday       Latte        1000
# 5   Wednesday       Latte        1000
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25

# %% [markdown]
# ### Iterating over a dataframe (df) with For Loop (df.iterrows())

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row)
    print("\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold       1000
# Name: 1, dtype: object
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold         1000
# Name: 2, dtype: object
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold        1000
# Name: 3, dtype: object
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold          1000
# Name: 4, dtype: object
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold          1000
# Name: 5, dtype: object
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# ...

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row["Units Sold"])
    print("\n\n")
# Out:
# 0
# 25
#
#
#
# 1
# 1000
#
#
#
# 2
# 1000
#
#
#
# 3
# 1000
#
#
#
# 4
# 1000
#
#
#
# 5
# 1000
#
#
#
# 6
# 40
#
#
#
# 7
# 30
#
#
#
# 8
# 45
#
#
#
# 9
# 35
#
#
#
# 10
# 45
#
#
#
# 11
# 35
#
#
#
# 12
# 45
#
#
#
# 13
# 35

# %% [markdown]
# ## Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# ### Filtering by Height and Weight

# %%
height = bios.loc[bios["height_cm"] > 215 , ["name","height_cm"]]
height
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %% [markdown]
# ### Sorted Height

# %%
height.sort_values(["height_cm"], ascending=False)[["name", "height_cm"]]
# Out:
#                          name  height_cm
# 89070                Yao Ming      226.0
# 5781           Tommy Burleson      223.0
# 6978          Arvydas Sabonis      223.0
# 120266           Zhang Zhaoxu      221.0
# 89075          Roberto Dueñas      221.0
# 5673           Gunther Behnke      221.0
# 5089       Viktor Pankrashkin      220.0
# 6504              Luc Longley      220.0
# 7188       Vladimir Tkachenko      220.0
# 118676        Dmitry Musersky      219.0
# 107408       Peter John Ramos      219.0
# 130460               Li Muhao      218.0
# 82100           Frédéric Weis      218.0
# 139365         Moustapha Fall      218.0
# 112337          Hamed Haddadi      218.0
# 6420            Jānis Krūmiņš      218.0
# 7376      Eurelijus Žukauskas      218.0
# 5796            Andy Campbell      218.0
# 5716                 Uwe Blab      218.0
# 5583     Paulinho Villas Boas      217.0
# 130461                Zhou Qi      217.0
# 112312           Stanko Barać      217.0
# ...

# %%
bios[bios["height_cm"] > 215][["name","height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[(bios["height_cm"] > 215) & (bios["born_country"] == "USA")]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %% [markdown]
# ## Flitering data

# %%
## "keith|het" is regex
bios[bios['name'].str.contains("keith|het" , case = False, regex=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[bios['born_country'].isin(["USA","FRA","GBR"]) & (bios['name'].str.contains("David"))]
# Out:
#         athlete_id             name   born_date        born_city  \
# 296            297      David Anear  1948-03-26        Lowestoft
# 585            587       David Pink  1939-12-31  Southend-on-Sea
# 747            751     David Humble  1967-03-06         Dumfries
# 2230          2240    David McGowan  1838-01-10     Perry County
# 2252          2262      David Milne  1939-01-29        Johnstone
# ...            ...              ...         ...              ...
# 139622      143098       David King  1994-06-13         Plymouth
# 143533      147186  Tierna Davidson  1998-09-19       Menlo Park
# 143725      147380  David Robertson  1985-04-09       Birmingham
# 143849      147505     David Taylor  1990-12-05             Reno
# 145422      149145  David Warsofsky  1990-05-30       Marshfield
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 296           England          GBR      Australia      175.0       80.0
# ...

# %%
bios[bios['born_country'].isin(["USA","FRA","GBR"]) & (bios['name'].str.startswith("Max"))]
# Out:
#         athlete_id                name   born_date           born_city  \
# 11              12         Max Decugis  1882-09-24          Paris XVIe
# 121            122         Max Woosnam  1892-09-06           Liverpool
# 3000          3012       Maxime Cochin  1927-05-27              Angers
# 3481          3493       Max Shacklady  1918-12-31  Barton-upon-Irwell
# 6000          6026          Max Dorigo  1936-09-02               Paris
# 11920        11985         Max Fresson  1912-04-23          Paris VIIe
# 16407        16523        Max Sciandri  1967-02-15               Derby
# 17551        17671        Max Baerlein  1879-12-13          Manchester
# 20862        21009     Maxine Mitchell  1917-07-22               Leroy
# 24974        25163          Max Samper  1938-06-29             Ganties
# 36997        37292        Maxwell Eley  1902-09-16             Samford
# 41860        42180       Maxime Landin  1855-04-24            Bagnolet
# ...

# %% [markdown]
# ### Regex (Regular Expressions)

# %%
# Find names that start with "A" and end with "n"
bios[bios['name'].str.contains(r'^A.*n$', regex=True)]
# Out:
#         athlete_id                    name   born_date      born_city  \
# 15              16  Adrien Fauchier-Magnan  1873-11-19    Paris VIIIe
# 28              29         Albert Lippmann         NaN            NaN
# 48              49           Alison Gordon  1962-12-31        Reading
# 61              62           Agatha Morton  1872-03-06       Halstead
# 92              93             Anne Gibson  1968-10-26       Dumfries
# ...            ...                     ...         ...            ...
# 145276      148997           Anton Persson  1995-02-26            NaN
# 145311      149033          Adam Reideborn  1992-01-18      Stockholm
# 145319      149041              Axel Brown  1992-04-02      Harrogate
# 145454      149180           Anna Hoffmann  2000-03-28        Madison
# 145457      149183          Alix Wilkinson  2000-08-02  Mammoth Lakes
#
#        born_region born_country                  NOC  height_cm  weight_kg  \
# ...

# %%
# Find names that contain a space (i.e., likely first and last name)
bios[bios['name'].str.contains(r'\s', regex=True)]
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
# Find names with exactly two words (first and last name)
bios[bios['name'].str.contains(r'^\w+\s\w+$', regex=True)]
# Out:
#         athlete_id                 name   born_date        born_city  \
# 1                2       Arnaud Boetsch  1969-04-01           Meulan
# 2                3         Jean Borotra  1898-08-13         Biarritz
# 3                4      Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5         Albert Canet  1878-04-17       Wandsworth
# 5                6    Nicolas Chatelain  1970-01-13           Amiens
# ...            ...                  ...         ...              ...
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
# Find names that contain a hyphen (e.g., "Jean-Paul")
bios[bios['name'].str.contains(r'-', regex=True)]
# Out:
#         athlete_id                    name   born_date           born_city  \
# 0                1   Jean-François Blanchy  1886-12-12            Bordeaux
# 15              16  Adrien Fauchier-Magnan  1873-11-19         Paris VIIIe
# 17              18    Jean-Philippe Gatien  1968-10-16                Alès
# 33              34  Jean-Pierre Samazeuilh  1891-01-17            Bordeaux
# 36              37    Pierre Verdé-Delisle  1877-05-16       Trie-la-Ville
# ...            ...                     ...         ...                 ...
# 145385      149108     Ashley Cain-Gribble  1995-07-22              Dallas
# 145388      149111          Jean-Luc Baker  1993-10-07             Burnley
# 145470      149197            Lee Chae-Eun  2006-04-11                 NaN
# 145490      149217             Sin Ye-Chan  1995-06-13                 NaN
# 145492      149219   Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
#
# ...

# %%
# Find names that contain three or more vowels in a row
bios[bios['name'].str.contains(r'[aeiouAEIOU]{3,}', regex=True)]
# Out:
#         athlete_id                      name   born_date         born_city  \
# 29              30  Édouard Mény de Marangue  1882-11-30         Paris VIe
# 31              32           Guillaume Raoux  1970-02-14  Bagnols-sur-Cèze
# 33              34    Jean-Pierre Samazeuilh  1891-01-17          Bordeaux
# 316            317           Robert Cogniaux  1934-05-29              Asse
# 321            322              Louis Delcon         NaN               NaN
# ...            ...                       ...         ...               ...
# 144940      148648            Yassine Aouich  1990-11-17            Ifrane
# 144995      148706                Sandra Eie  1995-11-14              Oslo
# 145155      148872    Maria Ioana Constantin  2001-01-05            Brașov
# 145201      148919               Alina Meier  1996-02-19             Davos
# 145475      149202             Zhou Xiaoyang  2002-09-24               NaN
#
# ...

# %%
# Find names that contain a capital letter followed by a lowercase letter, repeated (CamelCase)
bios[bios['name'].str.contains(r'[A-Z][a-z]+[A-Z][a-z]+', regex=True)]
# Out:
#         athlete_id                name   born_date        born_city  \
# 58              59        Kitty McKane  1896-05-07        Bayswater
# 59              60     Winifred McNair  1877-08-09       Donnington
# 375            376       John McDonald  1965-05-28          Halifax
# 611            613    Rachel McQuillan  1971-12-02      Mereweather
# 751            755   Sébastien LeBlanc  1973-12-27         Montréal
# ...            ...                 ...         ...              ...
# 145378      149101       Cole McDonald  2003-03-06        Park City
# 145390      149113       Timothy LeDuc  1990-05-04     Cedar Rapids
# 145413      149136     Marc McLaughlin  1999-07-26  North Billerica
# 145423      149146  Zachary DiGregorio  2001-11-14      West Medway
# 145431      149154     Sean FitzSimons  2000-09-22       Hood River
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 58              England          GBR  Great Britain        NaN        NaN
# ...

# %% [markdown]
# ### Query Function

# %%
##Instead of writing bios repeatedly
bios.query('born_country == "IND" and born_city == "Ahmedabad"' )
# Out:
#         athlete_id          name   born_date  born_city born_region  \
# 140241      143744  Ankita Raina  1993-01-11  Ahmedabad     Gujarat
#
#        born_country    NOC  height_cm  weight_kg died_date
# 140241          IND  India        NaN        NaN       NaN

# %% [markdown]
# # 34:42
